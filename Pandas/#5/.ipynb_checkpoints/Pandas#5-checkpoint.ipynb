# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
#                 date     views    likes  \
# 0      December 2021    404000    12000
# 1      February 2022    214000     6400
# 2     September 2021    412000    12000
# 3       October 2021    427000    12000
# 4       October 2021      2400       72
# ...              ...       ...      ...
# 5435   February 2006  15000000   458000
# 5436   February 2006  72000000  2100000
# 5437   February 2006   2900000    88000
# 5438   February 2006   2000000    60000
# 5439   February 2006   3600000   109000
#
#                                                    link
# 0     https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
# [5440 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['title', 'author', 'date', 'views', 'likes', 'link'], dtype='object')

# %%
df.columns = ['Title', 'Author', 'Date', 'Views', 'Likes', 'Link']
df
# Out:
#                                                   Title                Author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
#                 Date     Views    Likes  \
# 0      December 2021    404000    12000
# 1      February 2022    214000     6400
# 2     September 2021    412000    12000
# 3       October 2021    427000    12000
# 4       October 2021      2400       72
# ...              ...       ...      ...
# 5435   February 2006  15000000   458000
# 5436   February 2006  72000000  2100000
# 5437   February 2006   2900000    88000
# 5438   February 2006   2000000    60000
# 5439   February 2006   3600000   109000
#
#                                                    Link
# 0     https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
# [5440 rows x 6 columns]

# %%
df.columns = df.columns.str.replace('e', 'E')

# %%
df
# Out:
#                                                   TitlE                Author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
#                 DatE     ViEws    LikEs  \
# 0      December 2021    404000    12000
# 1      February 2022    214000     6400
# 2     September 2021    412000    12000
# 3       October 2021    427000    12000
# 4       October 2021      2400       72
# ...              ...       ...      ...
# 5435   February 2006  15000000   458000
# 5436   February 2006  72000000  2100000
# 5437   February 2006   2900000    88000
# 5438   February 2006   2000000    60000
# 5439   February 2006   3600000   109000
#
#                                                    Link
# 0     https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
# [5440 rows x 6 columns]

# %%
df.columns = ['Title', 'Author', 'Date']
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/rx/42yhbggj7bz_s3ndv3ztflb40000gn/T/ipykernel_30080/3395718031.py in <module>
# ----> 1 df.columns = ['Title', 'Author', 'Date']
#       2 df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      55
#      56         elif new_len != old_len:
# ---> 57             raise ValueError(
#      58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 6 elements, new values have 3 elements

# %%
df.rename(columns = {'TitlE': 'Başlıq', 'LikEs': 'Bəyənmələr'})
# Out:
#                                                  Başlıq                Author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
#                 DatE     ViEws  Bəyənmələr  \
# 0      December 2021    404000       12000
# 1      February 2022    214000        6400
# 2     September 2021    412000       12000
# 3       October 2021    427000       12000
# 4       October 2021      2400          72
# ...              ...       ...         ...
# 5435   February 2006  15000000      458000
# 5436   February 2006  72000000     2100000
# 5437   February 2006   2900000       88000
# 5438   February 2006   2000000       60000
# 5439   February 2006   3600000      109000
#
#                                                    Link
# 0     https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
# [5440 rows x 6 columns]

# %%
df.loc[0] = ['Test title', 'Test Author', 'January 2020', 250000, 25000, 'Test URL']

# %%
df
# Out:
#                                                   TitlE             Author  \
# 0                                            Test title        Test Author
# 1           The dark history of the overthrow of Hawaii      Sydney Iaukea
# 2        How play can spark new ideas for your business      Martin Reeves
# 3     Why is China appointing judges to combat clima...  James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it    Mahendra Singhi
# ...                                                 ...                ...
# 5435                    The best stats you've ever seen       Hans Rosling
# 5436                        Do schools kill creativity?   Sir Ken Robinson
# 5437                                Greening the ghetto      Majora Carter
# 5438                                   Simplicity sells        David Pogue
# 5439                        Averting the climate crisis            Al Gore
#
#                 DatE     ViEws    LikEs  \
# 0       January 2020    250000    25000
# 1      February 2022    214000     6400
# 2     September 2021    412000    12000
# 3       October 2021    427000    12000
# 4       October 2021      2400       72
# ...              ...       ...      ...
# 5435   February 2006  15000000   458000
# 5436   February 2006  72000000  2100000
# 5437   February 2006   2900000    88000
# 5438   February 2006   2000000    60000
# 5439   February 2006   3600000   109000
#
#                                                    Link
# 0                                              Test URL
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
# [5440 rows x 6 columns]

# %%
df.loc[1, ['Author', 'ViEws']]
# Out:
# Author    Sydney Iaukea
# ViEws            214000
# Name: 1, dtype: object

# %%
df.loc[1, ['Author', 'ViEws']] = ['Tim Berners-Lee', 500000]
df
# Out:
#                                                   TitlE             Author  \
# 0                                            Test title        Test Author
# 1           The dark history of the overthrow of Hawaii    Tim Berners-Lee
# 2        How play can spark new ideas for your business      Martin Reeves
# 3     Why is China appointing judges to combat clima...  James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it    Mahendra Singhi
# ...                                                 ...                ...
# 5435                    The best stats you've ever seen       Hans Rosling
# 5436                        Do schools kill creativity?   Sir Ken Robinson
# 5437                                Greening the ghetto      Majora Carter
# 5438                                   Simplicity sells        David Pogue
# 5439                        Averting the climate crisis            Al Gore
#
#                 DatE     ViEws    LikEs  \
# 0       January 2020    250000    25000
# 1      February 2022    500000     6400
# 2     September 2021    412000    12000
# 3       October 2021    427000    12000
# 4       October 2021      2400       72
# ...              ...       ...      ...
# 5435   February 2006  15000000   458000
# 5436   February 2006  72000000  2100000
# 5437   February 2006   2900000    88000
# 5438   February 2006   2000000    60000
# 5439   February 2006   3600000   109000
#
#                                                    Link
# 0                                              Test URL
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
# [5440 rows x 6 columns]

# %%
df['Author'] = df['Author'].str.replace(' ', '_')
df
# Out:
#                                                   TitlE             Author  \
# 0                                            Test title        Test_Author
# 1           The dark history of the overthrow of Hawaii    Tim_Berners-Lee
# 2        How play can spark new ideas for your business      Martin_Reeves
# 3     Why is China appointing judges to combat clima...  James_K._Thornton
# 4        Cement's carbon problem — and 2 ways to fix it    Mahendra_Singhi
# ...                                                 ...                ...
# 5435                    The best stats you've ever seen       Hans_Rosling
# 5436                        Do schools kill creativity?   Sir_Ken_Robinson
# 5437                                Greening the ghetto      Majora_Carter
# 5438                                   Simplicity sells        David_Pogue
# 5439                        Averting the climate crisis            Al_Gore
#
#                 DatE     ViEws    LikEs  \
# 0       January 2020    250000    25000
# 1      February 2022    500000     6400
# 2     September 2021    412000    12000
# 3       October 2021    427000    12000
# 4       October 2021      2400       72
# ...              ...       ...      ...
# 5435   February 2006  15000000   458000
# 5436   February 2006  72000000  2100000
# 5437   February 2006   2900000    88000
# 5438   February 2006   2000000    60000
# 5439   February 2006   3600000   109000
#
#                                                    Link
# 0                                              Test URL
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
# [5440 rows x 6 columns]

# %%
def artir(deyer):
    return deyer + 1

# %%
df['ViEws'] = df['ViEws'].apply(artir)
df
# Out:
#                                                   TitlE             Author  \
# 0                                            Test title        Test_Author
# 1           The dark history of the overthrow of Hawaii    Tim_Berners-Lee
# 2        How play can spark new ideas for your business      Martin_Reeves
# 3     Why is China appointing judges to combat clima...  James_K._Thornton
# 4        Cement's carbon problem — and 2 ways to fix it    Mahendra_Singhi
# ...                                                 ...                ...
# 5435                    The best stats you've ever seen       Hans_Rosling
# 5436                        Do schools kill creativity?   Sir_Ken_Robinson
# 5437                                Greening the ghetto      Majora_Carter
# 5438                                   Simplicity sells        David_Pogue
# 5439                        Averting the climate crisis            Al_Gore
#
#                 DatE     ViEws    LikEs  \
# 0       January 2020    250001    25000
# 1      February 2022    500001     6400
# 2     September 2021    412001    12000
# 3       October 2021    427001    12000
# 4       October 2021      2401       72
# ...              ...       ...      ...
# 5435   February 2006  15000001   458000
# 5436   February 2006  72000001  2100000
# 5437   February 2006   2900001    88000
# 5438   February 2006   2000001    60000
# 5439   February 2006   3600001   109000
#
#                                                    Link
# 0                                              Test URL
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
# [5440 rows x 6 columns]

# %%
df['ViEws'] = df['ViEws'].apply(lambda x: x - 1)
df
# Out:
#                                                   TitlE             Author  \
# 0                                            Test title        Test_Author
# 1           The dark history of the overthrow of Hawaii    Tim_Berners-Lee
# 2        How play can spark new ideas for your business      Martin_Reeves
# 3     Why is China appointing judges to combat clima...  James_K._Thornton
# 4        Cement's carbon problem — and 2 ways to fix it    Mahendra_Singhi
# ...                                                 ...                ...
# 5435                    The best stats you've ever seen       Hans_Rosling
# 5436                        Do schools kill creativity?   Sir_Ken_Robinson
# 5437                                Greening the ghetto      Majora_Carter
# 5438                                   Simplicity sells        David_Pogue
# 5439                        Averting the climate crisis            Al_Gore
#
#                 DatE     ViEws    LikEs  \
# 0       January 2020    250000    25000
# 1      February 2022    500000     6400
# 2     September 2021    412000    12000
# 3       October 2021    427000    12000
# 4       October 2021      2400       72
# ...              ...       ...      ...
# 5435   February 2006  15000000   458000
# 5436   February 2006  72000000  2100000
# 5437   February 2006   2900000    88000
# 5438   February 2006   2000000    60000
# 5439   February 2006   3600000   109000
#
#                                                    Link
# 0                                              Test URL
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
# [5440 rows x 6 columns]

# %%
df.apply(len)
# Out:
# TitlE     5440
# Author    5440
# DatE      5440
# ViEws     5440
# LikEs     5440
# Link      5440
# dtype: int64

# %%
df[['Link']] = df[['Link']].applymap(len)
df
# Out:
#       TitlE             Author            DatE     ViEws    LikEs  Link
# 0        10        Test_Author    January 2020    250000    25000     8
# 1        43    Tim_Berners-Lee   February 2022    500000     6400    79
# 2        46      Martin_Reeves  September 2021    412000    12000    82
# 3        56  James_K._Thornton    October 2021    427000    12000    94
# 4        46    Mahendra_Singhi    October 2021      2400       72    82
# ...     ...                ...             ...       ...      ...   ...
# 5435     31       Hans_Rosling   February 2006  15000000   458000    66
# 5436     27   Sir_Ken_Robinson   February 2006  72000000  2100000    65
# 5437     19      Majora_Carter   February 2006   2900000    88000    55
# 5438     16        David_Pogue   February 2006   2000000    60000    50
# 5439     27            Al_Gore   February 2006   3600000   109000    57
#
# [5440 rows x 6 columns]

# %%
df['Author']
# Out:
# 0             Test_Author
# 1         Tim_Berners-Lee
# 2           Martin_Reeves
# 3       James_K._Thornton
# 4         Mahendra_Singhi
#               ...
# 5435         Hans_Rosling
# 5436     Sir_Ken_Robinson
# 5437        Majora_Carter
# 5438          David_Pogue
# 5439              Al_Gore
# Name: Author, Length: 5440, dtype: object
