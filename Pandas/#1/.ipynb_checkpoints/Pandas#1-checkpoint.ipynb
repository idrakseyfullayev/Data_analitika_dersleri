# %%
import pandas as pd

# %%
df = pd.read_csv('turbo.csv')
df
# Out:
#           Price  Year Engine    Distance
# 0    12 700 AZN  2008  1.5 L  384 633 km
# 1    19 000 AZN  2010  1.8 L  316 656 km
# 2    13 900 AZN  2008  1.5 L  175 000 km
# 3    12 800 AZN  2007  1.5 L  210 000 km
# 4    14 500 AZN  2006  1.5 L  137 000 km
# ..          ...   ...    ...         ...
# 987  19 000 AZN  2012  1.8 L  167 000 km
# 988  10 000 AZN  2007  1.5 L  187 000 km
# 989  20 000 AZN  2007  1.5 L  150 000 km
# 990  13 900 AZN  2008  1.5 L  175 000 km
# 991  12 200 AZN  2008  1.5 L  150 000 km
#
# [992 rows x 4 columns]

# %%
df.shape
# Out:
# (992, 4)

# %%
df.head()
# Out:
#         Price  Year Engine    Distance
# 0  12 700 AZN  2008  1.5 L  384 633 km
# 1  19 000 AZN  2010  1.8 L  316 656 km
# 2  13 900 AZN  2008  1.5 L  175 000 km
# 3  12 800 AZN  2007  1.5 L  210 000 km
# 4  14 500 AZN  2006  1.5 L  137 000 km

# %%
df.head(10)
# Out:
#         Price  Year Engine    Distance
# 0  12 700 AZN  2008  1.5 L  384 633 km
# 1  19 000 AZN  2010  1.8 L  316 656 km
# 2  13 900 AZN  2008  1.5 L  175 000 km
# 3  12 800 AZN  2007  1.5 L  210 000 km
# 4  14 500 AZN  2006  1.5 L  137 000 km
# 5  14 500 AZN  2011  1.8 L  140 000 km
# 6  12 900 AZN  2008  1.5 L  237 000 km
# 7  13 100 AZN  2007  1.5 L  195 300 km
# 8  10 900 AZN  2007  1.5 L  239 000 km
# 9  12 200 AZN  2008  1.5 L  330 000 km

# %%
df.tail()
# Out:
#           Price  Year Engine    Distance
# 987  19 000 AZN  2012  1.8 L  167 000 km
# 988  10 000 AZN  2007  1.5 L  187 000 km
# 989  20 000 AZN  2007  1.5 L  150 000 km
# 990  13 900 AZN  2008  1.5 L  175 000 km
# 991  12 200 AZN  2008  1.5 L  150 000 km

# %%
df.tail(10)
# Out:
#           Price  Year Engine    Distance
# 982  13 500 AZN  2008  1.5 L  235 000 km
# 983  11 000 AZN  2008  1.5 L  222 222 km
# 984  12 600 AZN  2007  1.5 L  286 463 km
# 985  14 000 AZN  2007  1.5 L  185 000 km
# 986  16 700 AZN  2011  1.8 L  160 000 km
# 987  19 000 AZN  2012  1.8 L  167 000 km
# 988  10 000 AZN  2007  1.5 L  187 000 km
# 989  20 000 AZN  2007  1.5 L  150 000 km
# 990  13 900 AZN  2008  1.5 L  175 000 km
# 991  12 200 AZN  2008  1.5 L  150 000 km

# %%
pd.options.display.max_rows
# Out:
# 100

# %%
df.head(70)
# Out:
#          Price  Year Engine    Distance
# 0   12 700 AZN  2008  1.5 L  384 633 km
# 1   19 000 AZN  2010  1.8 L  316 656 km
# 2   13 900 AZN  2008  1.5 L  175 000 km
# 3   12 800 AZN  2007  1.5 L  210 000 km
# 4   14 500 AZN  2006  1.5 L  137 000 km
# 5   14 500 AZN  2011  1.8 L  140 000 km
# 6   12 900 AZN  2008  1.5 L  237 000 km
# 7   13 100 AZN  2007  1.5 L  195 300 km
# 8   10 900 AZN  2007  1.5 L  239 000 km
# 9   12 200 AZN  2008  1.5 L  330 000 km
# 10  13 500 AZN  2008  1.5 L  210 000 km
# 11  18 200 AZN  2010  1.8 L  115 000 km
# 12  13 300 AZN  2008  1.5 L  127 000 km
# 13  13 800 AZN  2007  1.5 L  191 000 km
# 14  12 400 AZN  2007  1.5 L  257 000 km
# 15  13 800 AZN  2007  1.5 L  242 000 km
# 16  14 100 AZN  2009  1.5 L  219 000 km
# 17  12 900 AZN  2009  1.5 L  182 300 km
# 18  13 500 AZN  2009  1.5 L  203 000 km
# 19  19 800 AZN  2012  1.8 L  190 466 km
# 20  13 300 AZN  2007  1.5 L  140 000 km
# 21  18 700 AZN  2012  1.8 L  199 000 km
# ...

# %%
df.head(110)
# Out:
#           Price  Year Engine    Distance
# 0    12 700 AZN  2008  1.5 L  384 633 km
# 1    19 000 AZN  2010  1.8 L  316 656 km
# 2    13 900 AZN  2008  1.5 L  175 000 km
# 3    12 800 AZN  2007  1.5 L  210 000 km
# 4    14 500 AZN  2006  1.5 L  137 000 km
# ..          ...   ...    ...         ...
# 105  21 400 AZN  2012  1.8 L  149 050 km
# 106  13 400 AZN  2007  1.5 L  188 000 km
# 107  13 400 AZN  2007  1.5 L  210 000 km
# 108  13 500 AZN  2008  1.5 L  337 962 km
# 109  15 900 AZN  2011  1.8 L  131 000 km
#
# [110 rows x 4 columns]

# %%
pd.options.display.max_rows = 120

# %%
df.head(110)
# Out:
#           Price  Year Engine    Distance
# 0    12 700 AZN  2008  1.5 L  384 633 km
# 1    19 000 AZN  2010  1.8 L  316 656 km
# 2    13 900 AZN  2008  1.5 L  175 000 km
# 3    12 800 AZN  2007  1.5 L  210 000 km
# 4    14 500 AZN  2006  1.5 L  137 000 km
# 5    14 500 AZN  2011  1.8 L  140 000 km
# 6    12 900 AZN  2008  1.5 L  237 000 km
# 7    13 100 AZN  2007  1.5 L  195 300 km
# 8    10 900 AZN  2007  1.5 L  239 000 km
# 9    12 200 AZN  2008  1.5 L  330 000 km
# 10   13 500 AZN  2008  1.5 L  210 000 km
# 11   18 200 AZN  2010  1.8 L  115 000 km
# 12   13 300 AZN  2008  1.5 L  127 000 km
# 13   13 800 AZN  2007  1.5 L  191 000 km
# 14   12 400 AZN  2007  1.5 L  257 000 km
# 15   13 800 AZN  2007  1.5 L  242 000 km
# 16   14 100 AZN  2009  1.5 L  219 000 km
# 17   12 900 AZN  2009  1.5 L  182 300 km
# 18   13 500 AZN  2009  1.5 L  203 000 km
# 19   19 800 AZN  2012  1.8 L  190 466 km
# 20   13 300 AZN  2007  1.5 L  140 000 km
# 21   18 700 AZN  2012  1.8 L  199 000 km
# ...
