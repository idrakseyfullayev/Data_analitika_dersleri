# %%
import pandas as pd

# %%
df = pd.read_csv('billionaire.csv')
df
# Out:
#                           Name NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos   $177 B  United States         Amazon     1
# 1                    Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family   $150 B         France           LVMH     3
# 3                   Bill Gates   $124 B  United States      Microsoft     4
# 4              Mark Zuckerberg    $97 B  United States       Facebook     5
# ...                        ...      ...            ...            ...   ...
# 2750         Daniel Yong Zhang     $1 B          China     e-commerce  2674
# 2751             Zhang Yuqiang     $1 B          China     Fiberglass  2674
# 2752             Zhao Meiguang     $1 B          China    gold mining  2674
# 2753            Zhong Naixiong     $1 B          China   conglomerate  2674
# 2754           Zhou Wei family     $1 B          China       Software  2674
#
#        Age          Industry
# 0     57.0        Technology
# 1     49.0        Automotive
# 2     72.0  Fashion & Retail
# 3     65.0        Technology
# 4     36.0        Technology
# ...    ...               ...
# 2750  49.0        Technology
# 2751  65.0     Manufacturing
# 2752  58.0   Metals & Mining
# 2753  58.0       Diversified
# 2754  54.0        Technology
#
# [2755 rows x 7 columns]

# %%
df['NetWorth'] = df['NetWorth'].str.replace(' B', '')

# %%
df['NetWorth'] = df['NetWorth'].str.replace('$', '')
# Out:
# /var/folders/rx/42yhbggj7bz_s3ndv3ztflb40000gn/T/ipykernel_38366/226033256.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['NetWorth'] = df['NetWorth'].str.replace('$', '')

# %%
df
# Out:
#                           Name NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos      177  United States         Amazon     1
# 1                    Elon Musk      151  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family      150         France           LVMH     3
# 3                   Bill Gates      124  United States      Microsoft     4
# 4              Mark Zuckerberg       97  United States       Facebook     5
# ...                        ...      ...            ...            ...   ...
# 2750         Daniel Yong Zhang        1          China     e-commerce  2674
# 2751             Zhang Yuqiang        1          China     Fiberglass  2674
# 2752             Zhao Meiguang        1          China    gold mining  2674
# 2753            Zhong Naixiong        1          China   conglomerate  2674
# 2754           Zhou Wei family        1          China       Software  2674
#
#        Age          Industry
# 0     57.0        Technology
# 1     49.0        Automotive
# 2     72.0  Fashion & Retail
# 3     65.0        Technology
# 4     36.0        Technology
# ...    ...               ...
# 2750  49.0        Technology
# 2751  65.0     Manufacturing
# 2752  58.0   Metals & Mining
# 2753  58.0       Diversified
# 2754  54.0        Technology
#
# [2755 rows x 7 columns]

# %%
df['NetWorth'].median()
# Out:
# 2.3

# %%
df.median()
# Out:
# /var/folders/rx/42yhbggj7bz_s3ndv3ztflb40000gn/T/ipykernel_38366/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# NetWorth       2.3
# Rank        1362.0
# Age           63.0
# dtype: float64

# %%
df.describe()
# Out:
#               Rank          Age
# count  2755.000000  2676.000000
# mean   1345.663521    63.113602
# std     772.669811    13.445153
# min       1.000000    18.000000
# 25%     680.000000    54.000000
# 50%    1362.000000    63.000000
# 75%    2035.000000    73.000000
# max    2674.000000    99.000000

# %%
df['Rank'].count()
# Out:
# 2755

# %%
df['Age'].value_counts()
# Out:
# 57.0    93
# 58.0    92
# 59.0    85
# 56.0    84
# 71.0    78
#         ..
# 27.0     1
# 18.0     1
# 26.0     1
# 99.0     1
# 25.0     1
# Name: Age, Length: 76, dtype: int64

# %%
df_grouped = df.groupby('Country')
df_grouped

# %%
df_grouped.get_group('Turkey')
# Out:
#                      Name NetWorth Country                         Source  \
# 427           Murat Ulker      6.3  Turkey                           food
# 660          Erman Ilicak      4.4  Turkey                   construction
# 1044    Ferit Faik Sahenk        3  Turkey                    diversified
# 1156         Filiz Sahenk      2.8  Turkey                    diversified
# 1366  Semahat Sevim Arsel      2.3  Turkey                    diversified
# 1367       Sezai Bacaksiz      2.3  Turkey                    diversified
# 1398    Mustafa Rahmi Koc      2.3  Turkey                    diversified
# 1414        Nihat Ozdemir      2.3  Turkey                    diversified
# 1541        Mustafa Kucuk      2.1  Turkey                 fashion retail
# 1595    Ibrahim Erdemoglu        2  Turkey                         carpet
# 1650        Hamdi Ulukaya        2  Turkey                   greek yogurt
# 1681    Bulent Eczacibasi      1.9  Turkey   pharmaceuticals, diversified
# 1702           Ipek Kirac      1.9  Turkey                    diversified
# 1765     Faruk Eczacibasi      1.8  Turkey   pharmaceuticals, diversified
# 1768        Ali Erdemoglu      1.8  Turkey                         carpet
# 1803        Husnu Ozyegin      1.8  Turkey           finance, diversified
# 2001         Deniz Sahenk      1.6  Turkey                    diversified
# 2035  Hamdi Akin & family      1.5  Turkey                    diversified
# 2043          Ahmet Calik      1.5  Turkey  energy, banking, construction
# 2167  Sefik Yilmaz Dizdar      1.4  Turkey                 fashion retail
# 2267      Mehmet Aydinlar      1.3  Turkey                      hospitals
# 2287         Turgay Ciner      1.3  Turkey                    diversified
# 2398          Aydin Dogan      1.2  Turkey                          media
# 2413   Mehmet Nazif Gunal      1.2  Turkey          tourism, construction
# 2636    Mehmet Sinan Tara      1.1  Turkey                   construction
# 2672    Ahmet Nazif Zorlu      1.1  Turkey                    diversified
# 2738          Murat Vargi        1  Turkey                        telecom
#
#       Rank   Age                    Industry
# 427    421  62.0             Food & Beverage
# 660    655  53.0  Construction & Engineering
# 1044  1008  57.0                 Diversified
# 1156  1111  54.0                 Diversified
# 1366  1362  92.0                 Diversified
# 1367  1362  71.0                 Diversified
# 1398  1362  90.0                 Diversified
# 1414  1362  71.0                 Diversified
# 1541  1517  57.0            Fashion & Retail
# 1595  1580  58.0               Manufacturing
# 1650  1580  48.0             Food & Beverage
# 1681  1664  71.0                 Diversified
# 1702  1664  36.0                 Diversified
# 1765  1750  66.0                 Diversified
# 1768  1750  61.0               Manufacturing
# 1803  1750  76.0       Finance & Investments
# 2001  1931  75.0                 Diversified
# 2035  2035  66.0                 Diversified
# 2043  2035  63.0                 Diversified
# 2167  2141  83.0            Fashion & Retail
# 2267  2263  64.0                  Healthcare
# 2287  2263  65.0                 Diversified
# 2398  2378  84.0       Media & Entertainment
# 2413  2378  73.0                 Diversified
# 2636  2524  62.0  Construction & Engineering
# 2672  2524  76.0                 Diversified
# 2738  2674  73.0                     Telecom

# %%
df['Age'].agg(['median', 'sum'])
# Out:
# median        63.0
# sum       168892.0
# Name: Age, dtype: float64

# %%
df2 = pd.read_csv('data.csv')
df2
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
#                 date     views    likes  \
# 0      December 2021    404000    12000
# 1      February 2022    214000     6400
# 2     September 2021    412000    12000
# 3       October 2021    427000    12000
# 4       October 2021      2400       72
# ...              ...       ...      ...
# 5435   February 2006  15000000   458000
# 5436   February 2006  72000000  2100000
# 5437   February 2006   2900000    88000
# 5438   February 2006   2000000    60000
# 5439   February 2006   3600000   109000
#
#                                                    link
# 0     https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
# [5440 rows x 6 columns]

# %%
df3 = pd.concat([df, df2], axis = 'columns')
df3
# Out:
#                           Name NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos      177  United States         Amazon   1.0
# 1                    Elon Musk      151  United States  Tesla, SpaceX   2.0
# 2     Bernard Arnault & family      150         France           LVMH   3.0
# 3                   Bill Gates      124  United States      Microsoft   4.0
# 4              Mark Zuckerberg       97  United States       Facebook   5.0
# ...                        ...      ...            ...            ...   ...
# 5435                       NaN      NaN            NaN            NaN   NaN
# 5436                       NaN      NaN            NaN            NaN   NaN
# 5437                       NaN      NaN            NaN            NaN   NaN
# 5438                       NaN      NaN            NaN            NaN   NaN
# 5439                       NaN      NaN            NaN            NaN   NaN
#
#        Age          Industry  \
# 0     57.0        Technology
# 1     49.0        Automotive
# 2     72.0  Fashion & Retail
# 3     65.0        Technology
# 4     36.0        Technology
# ...    ...               ...
# 5435   NaN               NaN
# 5436   NaN               NaN
# 5437   NaN               NaN
# 5438   NaN               NaN
# 5439   NaN               NaN
#
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
#                 date     views    likes  \
# 0      December 2021    404000    12000
# 1      February 2022    214000     6400
# 2     September 2021    412000    12000
# 3       October 2021    427000    12000
# 4       October 2021      2400       72
# ...              ...       ...      ...
# 5435   February 2006  15000000   458000
# 5436   February 2006  72000000  2100000
# 5437   February 2006   2900000    88000
# 5438   February 2006   2000000    60000
# 5439   February 2006   3600000   109000
#
#                                                    link
# 0     https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
# [5440 rows x 13 columns]
